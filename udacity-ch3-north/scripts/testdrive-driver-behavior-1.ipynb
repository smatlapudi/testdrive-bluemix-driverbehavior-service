// %% [markdown]
// # Test Driving IBM Watson IoT Driver Behavior Service on Bluemix
// Below are the high level steps involved in processing input data to get the driver behavior information.
//
// - Scan the input raw vehicle prob data.
// - Use Context Mapping service to map raw vehicle prob data to geospatial data. This is optional step. But it enhances the quality of the analyzed driver behavior results.
//  - Get map-matched car probe data by using the mapMatching API.
//  - Get road type data with the getLinkInformation API.
// - Analyze the uploaded data by submitting a job request using Driving Behavior service's sendJobRequest API.
// - Get the detailed driver behavior information from analyzed data by using Driving Behavior service's getAnalyzedTripSummaryList and getAnalyzedTripInfo APIs

// %% [markdown]
// ## 1. Initialization code
// - Using scalaj-http library for making REST calls, so add this jar
// - Using play-json library for Json parsing of RESt results, add this jar
// - Required imports

// %%
%AddJar -magic http://central.maven.org/maven2/org/scalaj/scalaj-http_2.10/2.3.0/scalaj-http_2.10-2.3.0.jar
%AddJar -magic http://central.maven.org/maven2/com/typesafe/play/play-json_2.10/2.4.6/play-json_2.10-2.4.6.jar
import scalaj.http._
import play.api.libs.json._
import scala.util.{Try,Success,Failure}
// Out:
// Using cached version of scalaj-http_2.10-2.3.0.jar
// Using cached version of play-json_2.10-2.4.6.jar

// %% [markdown]
// ## 2. Read Input raw trip data
// - Input format is in json lines
// - Read, parse and convert to TripDataPoint RDD

// %%
// Quick way to load test dataset created
val inputTestDataUrl = "https://raw.githubusercontent.com/smatlapudi/testdrive-bluemix-driverbehavior-service/master/testdata/udacity-ch3-north.json"
val inputTestData =  scala.io.Source.fromURL(inputTestDataUrl).getLines.to[collection.immutable.Seq]
val tripDataLines_rdd = sc.parallelize(inputTestData)

// %%
// TripData class
case class TripDataPoint(timestamp: String, heading: Double, speed: Double, latitude: Double, longitude: Double )
// Utility function to covert json line to Scala Object
def parseTripDataLine(jsonLine: String): Option[TripDataPoint] = {
    val jsObj  = Json.parse(jsonLine)
    implicit val modelFormat = Json.format[TripDataPoint]
    Json.fromJson[TripDataPoint](jsObj).asOpt //ignoring any possible error messages here
}
// Convert tripDataLines_rdd to TripRdd 
val tripData_rdd = tripDataLines_rdd.map(parseTripDataLine).flatMap(_.toSeq)
tripData_rdd.cache
tripData_rdd.take(5).foreach(println)
// Out:
// TripDataPoint(2016-11-17T22:23:03Z,357.4195341311482,15.085078615161539,37.4019584656,-122.114883423)
// TripDataPoint(2016-11-17T22:23:04Z,357.12198437345154,15.001162178540001,37.4020271301,-122.115020752)
// TripDataPoint(2016-11-17T22:23:05Z,355.95965463973073,14.618271412569998,37.4021072388,-122.115158081)
// TripDataPoint(2016-11-17T22:23:06Z,330.98606173371456,14.17331637527667,37.4021835327,-122.115287781)
// TripDataPoint(2016-11-17T22:23:07Z,351.05080395396425,13.715587838680003,37.4022636414,-122.115409851)

// %% [markdown]
// ## 3. Map the TripData using MapInsights mapservice
// - Parameter initialization
// - Call mapservice matching endpoint
// - Get Link Information from Mapped TripData to get Road Type

// %% [markdown]
// ### Parameter initialization

// %%
val contextMapServiceProps = Map(
    "match_api_url" ->  "https://automotive.internetofthings.ibmcloud.com/mapinsights/mapservice/map/matching",
    "link_api_url" ->  "https://automotive.internetofthings.ibmcloud.com/mapinsights/mapservice/link",
    "tenant_id" -> "SOME_VALUE", // Get this from Context Mapping Service DashBoard in Bluemix
    "username" -> "SOME_VALUE",         // Get this from Context Mapping Service DashBoard in Bluemix
    "password" -> "SOME_VALUE",   // Get this from Context Mapping Service DashBoard in Bluemix
    "mo_id" -> "udacity-ch3",         // Dummy device id value for testing
    "trip_id" -> "udacity-ch3-north"  // Dummy value for testing
)
val contextMapServiceInfo = sc.broadcast(contextMapServiceProps)

// %% [markdown]
// ### Use mapservice matching endpoint
//  - Defined required case classes and utility functions
//  - Make REST call to match raw coordinates to map matched coordinates
//  - Refer api documentation at https://developer.ibm.com/api/view/id-263:title-IBM_Watson_IoT_Context_Mapping#Mapmatching

// %%
//Case classes to store input and rest results
case class RestCallResult(code: Int, body: String)
case class MappedTripAttr(   
    link_id: String,
    matched_map_id: Double,
    matched_longitude: Double,
    matched_latitude: Double,
    matched_heading: Double
)
case class MappedTripData(rawAttr: TripDataPoint, mappedAttr: Option[MappedTripAttr])

// Utility function to covert Rest Results from json to Scala Object
// Note that API result is a list of Objects
def parseMappedTripDataJson(jsonLine: String): Option[List[MappedTripAttr]] = {
    val jsObj  = Json.parse(jsonLine)
    implicit val modelFormat = Json.format[MappedTripAttr]
    Json.fromJson[List[MappedTripAttr]](jsObj).asOpt //ignoring any possible error messages here
}

// %%
//Make map service matching endpoint calls here
val mappedTripData_rdd = tripData_rdd.mapPartitions{iter =>
    val serviceProps = contextMapServiceInfo.value
    iter.map { tdp =>
        val response = Http(serviceProps.get("match_api_url").get).
            param("tenant_id", serviceProps.get("tenant_id").get).
            auth( serviceProps.get("username").get, serviceProps.get("password").get).
            param("mo_id",     serviceProps.get("mo_id").get).
            param("trip_id",   serviceProps.get("trip_id").get).
            param("timestamp", s"${tdp.timestamp}").
            param("heading",   s"${tdp.heading}").
            param("latitude",  s"${tdp.latitude}").
            param("longitude", s"${tdp.longitude}").
            option(HttpOptions.readTimeout(30000)).asString
              
        response.code match {
            case 200 => parseMappedTripDataJson(response.body) match {
                // from Option[List[MappedTripAttr]] ==> MappedTripData
                case Some(matchedAttr) => MappedTripData( tdp, Some(matchedAttr(0)))
                case _ => MappedTripData(tdp, None)
            }
            case _ => MappedTripData(tdp, None)
        }
    }
}

mappedTripData_rdd.cache
println("Output Sample:")
mappedTripData_rdd.take(2).foreach(println)
// Out:
// Output Sample:
// MappedTripData(TripDataPoint(2016-11-17T22:23:34Z,1.9000000386407154,0.0,37.4032897949,-122.116546631),Some(MappedTripAttr(258517197000,5.0,-122.1166795,37.4032391,30.27786064506597)))
// MappedTripData(TripDataPoint(2016-11-17T22:52:41Z,0.5999999953495317,0.0,37.4902687073,-122.239448547),Some(MappedTripAttr(95876262000,5.0,-122.2394565851877,37.49026589386588,344.2528605654734)))

// %% [markdown]
// ### Link Information from Mapped TripData
//  - Get distinct link ids
//  - Call mapservice link endpoint
//  - Parse output to get the the road type. Possible values are
//    ( Motorway=1, Urban Highway=2,  Urban Primary=3, Urban Road=4, Others = 5)

// %%
println(mappedTripData_rdd.count)

// %%
// from MappedTripData[TripDataPoint, Option[MappedTripAttr]] -> Some(link_id) -> link_id -> distinct Link_ids
val uniqueLinks = mappedTripData_rdd.map(_.mappedAttr.map(_.link_id)).flatMap(_.toSeq).distinct
uniqueLinks.cache
println("Sample link_ids:")
uniqueLinks.take(2).foreach(println)
// Out:
// Sample link_ids:
// 95876262000
// 258517197000

// %% [markdown]
// ## Now get Link Information for above results
// - Refer api documentation at https://developer.ibm.com/api/view/id-263:title-IBM_Watson_IoT_Context_Mapping#Getlinkinformation

// %%
// Utilityfunction to extract road_type from Rest Results from json to Scala Object
// that is json field from links[0].properties.type
def extractRoadTypeFromLinkInfoJson(jsonLine: String): Try[String] = {
    val jsonValue  = Json.parse(jsonLine)
    Try( ((jsonValue \ "links")(0) \ "properties" \ "type").as[String] )
}

case class LinkRoadType(link_id: String, road_type: String)

//Make map service link endpoint calls here
val linkInfo_rdd = uniqueLinks.repartition(10).mapPartitions{iter =>
    val serviceProps = contextMapServiceInfo.value
    iter.map { link_id =>
        val response = Http(serviceProps.get("link_api_url").get).
            param("tenant_id", serviceProps.get("tenant_id").get).
            auth(serviceProps.get("username").get, serviceProps.get("password").get).
            param("link_id", link_id).
            option(HttpOptions.readTimeout(30000)).asString
        response.code match {
            case 200 => extractRoadTypeFromLinkInfoJson(response.body) match {
                case Success(road_type) => LinkRoadType(link_id, road_type)
                case _ => LinkRoadType(link_id, "5") //default to road type 5 (Others)
            }
            case _ => LinkRoadType(link_id, "5") //default to road type 5
        }
    }
}
linkInfo_rdd.cache
linkInfo_rdd.count
// Out:
// 2

// %% [markdown]
// ### Prepare Data for Driver Insights service - Car Prob Data endpoint
// - Refer api documentation at https://developer.ibm.com/api/view/id-261:title-IBM_Watson_IoT_Driver_Behavior#Sendcarprobedata
// - join MappedTripData with LinkInfomation to add Road Type to all mapped records

// %%
val l_rdd = mappedTripData_rdd.map( x => (x.mappedAttr.fold("NA")(_.link_id), x) )
val r_rdd =  linkInfo_rdd.map( x => (x.link_id, x.road_type))
val mappedTripDataWithRoadInfo_rdd = l_rdd.leftOuterJoin(r_rdd)

//class for car prob data record
case class CarProbData(
    trip_id: String,
    timestamp: String,
    matched_heading: Double,
    speed: Double,
    matched_longitude: Double,
    mo_id: String,
    longitude: Double,
    matched_latitude: Double,
    matched_link_id: Option[String],
    latitude: Double,
    road_type: Option[String],
    heading: Double
)

val carProbData_rdd = mappedTripDataWithRoadInfo_rdd.map { 
    case(link_id, (mappedTripData, road_type_opt)) =>
        val tripDataAttr = mappedTripData.rawAttr
        val mappedTripAttrOpt = mappedTripData.mappedAttr
        CarProbData(
            trip_id            = contextMapServiceInfo.value.get("trip_id").get,
            timestamp          = tripDataAttr.timestamp,
            matched_heading    = mappedTripAttrOpt.fold(tripDataAttr.heading)(_.matched_heading),
            speed              = tripDataAttr.speed,
            matched_longitude  = mappedTripAttrOpt.fold(tripDataAttr.longitude)(_.matched_longitude),
            mo_id              = contextMapServiceInfo.value.get("mo_id").get,
            longitude          = tripDataAttr.longitude,
            matched_latitude   = mappedTripAttrOpt.fold(tripDataAttr.latitude)(_.matched_latitude),
            matched_link_id    = if(link_id != "NA") Some(link_id) else None,
            latitude           = tripDataAttr.latitude,
            road_type          = road_type_opt,
            heading            = tripDataAttr.heading
        )    
}
carProbData_rdd.cache
carProbData_rdd.take(2).foreach(println)
// Out:
// CarProbData(udacity-ch3-north,2016-11-17T22:23:34Z,30.27786064506597,0.0,-122.1166795,udacity-ch3,-122.116546631,37.4032391,Some(258517197000),37.4032897949,Some(5),1.9000000386407154)
// CarProbData(udacity-ch3-north,2016-11-17T22:52:41Z,344.2528605654734,0.0,-122.23945657541587,udacity-ch3,-122.239448547,37.490265866252045,Some(95876262000),37.4902687073,Some(5),0.5999999953495317)

// %% [markdown]
// ## Send Car Probe Data to Driver Insights service
// - Initialize service related paramaters
// - Send the data by calling the serive

// %%
val driverInsightsServiceProps = Map(
    "carprobe_datastore_url" ->  "https://automotive.internetofthings.ibmcloud.com/driverinsights/datastore/carProbe",
    "job_control_url"        -> "https://automotive.internetofthings.ibmcloud.com/driverinsights/jobcontrol/job",
    "trip_summary_list_url"  -> "https://automotive.internetofthings.ibmcloud.com/driverinsights/drbresult/tripSummaryList",
    "trip_analytics_url"     -> "https://automotive.internetofthings.ibmcloud.com/driverinsights/drbresult/trip",
    "tenant_id" -> "SOME_VALUE",       // Get this value from Driver Behavior Service Dashboard
    "username" -> "SOME_VALUE",        // Get this value from Driver Behavior Service Dashboard
    "password" -> "SOME_VALUE",        // Get this value from Driver Behavior Service Dashboard
    "mo_id" -> "udacity-ch3",          // Dummy device_id for this testing
    "trip_id" -> "udacity-ch3-north"   // Dummy trip_id for this testing 
)
val driverInsightsServiceInfo = sc.broadcast(driverInsightsServiceProps)

// %% [markdown]
// #### Now we have all the required attributes in right format, send the data

// %%
// utility function to covert CarProbData object to json string
def CarProbData2JsonString(modelObj: CarProbData): String = {
    implicit val modelFormat = Json.writes[CarProbData]
    Json.toJson[CarProbData](modelObj).toString
}

//Make driver insights card prob datastore alls here
val carProbDataResult_rdd = carProbData_rdd.mapPartitions{iter =>
    val serviceProps = driverInsightsServiceInfo.value
    iter.map { carProbData =>
        val data2post = CarProbData2JsonString(carProbData)
        val response = Http(serviceProps.get("carprobe_datastore_url").get).
            param("tenant_id", serviceProps.get("tenant_id").get).
            auth( serviceProps.get("username").get, serviceProps.get("password").get).
            option(HttpOptions.readTimeout(30000)).
            header("accept", "application/json").
            header("content-type", "application/json").
            postData(data2post).asString
        (response.code, response.body)
    }
}
carProbDataResult_rdd.cache
val results = carProbDataResult_rdd.map( x => (x._1, 1)).reduceByKey( _ + _).collect
results.foreach( x => println(s"code: ${x._1}\tcount: ${x._2}"))

// %% [markdown]
// ## Get Driver Behavior for Above Trip
// - Send a Driver Insights Job Request to Analyse the above Car probe Data
// - Check  Job completion status
// - Get the Analyzed Trip Information

// %% [markdown]
// ### Send a Job Request to Analyze the Car Prob Data
// - Refer API documentation at https://developer.ibm.com/api/view/id-261:title-IBM_Watson_IoT_Driver_Behavior#SendJobRequest

// %%
val from_date = "2016-11-17"
val to_date   = "2016-11-17"
val sendJobRequest2Post = s"""{"from":"$from_date", "to":"$to_date"}"""
println(s"postData: ${sendJobRequest2Post}")

val response = Http(driverInsightsServiceProps.get("job_control_url").get).
    param("tenant_id", driverInsightsServiceProps.get("tenant_id").get).
    auth(driverInsightsServiceProps.get("username").get, driverInsightsServiceProps.get("password").get).
    option(HttpOptions.readTimeout(30000)).
    header("accept", "application/json").
    header("content-type", "application/json").
    postData(sendJobRequest2Post).asString

println(s"response.code: ${response.code}")
println(response.body)
// Out:
// postData: {"from":"2016-11-17", "to":"2016-11-17"}
// response.code: 200
// {
//   "job_id" : "247b07b4-affb-45cd-b041-fa37443f7147"
// }

// %% [markdown]
// ### Check  Job Completion Status
// - Refer API documentation at https://developer.ibm.com/api/view/id-261:title-IBM_Watson_IoT_Driver_Behavior#getjobinformation

// %%
val job_id = "247b07b4-affb-45cd-b041-fa37443f7147"
val response = Http(driverInsightsServiceProps.get("job_control_url").get).
    param("tenant_id", driverInsightsServiceProps.get("tenant_id").get).
    auth(driverInsightsServiceProps.get("username").get, driverInsightsServiceProps.get("password").get).
    param("job_id", job_id).
    option(HttpOptions.readTimeout(30000)).
    header("accept", "application/json").
    header("content-type", "application/json").asString

println(s"response.code: ${response.code}")
println(response.body)
// Out:
// response.code: 200
// {
//   "from" : "2016-11-17",
//   "to" : "2016-11-17",
//   "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//   "job_id" : "247b07b4-affb-45cd-b041-fa37443f7147",
//   "job_submit_time" : 1480987489902,
//   "job_status" : "SUCCEEDED"
// }

// %% [markdown]
// ### Get the Analyzed Trip Information
// - Refer API documentation at https://developer.ibm.com/api/view/id-261:title-IBM_Watson_IoT_Driver_Behavior#Getanalyzedtripinformation
// - First get analyzed trip summary list which includes the services generated trip_uuid
// - get the Trip Information with Driver Behavior using trip_uuid

// %%
val job_id = "247b07b4-affb-45cd-b041-fa37443f7147"
val response = Http(driverInsightsServiceProps.get("trip_summary_list_url").get).
    param("tenant_id", driverInsightsServiceProps.get("tenant_id").get).
    param("job_id", job_id).
    auth(driverInsightsServiceProps.get("username").get, driverInsightsServiceProps.get("password").get).
    option(HttpOptions.readTimeout(30000)).
    header("accept", "application/json").
    header("content-type", "application/json").asString
                    
println(s"response.code: ${response.code}")
println(response.body)
// Out:
// response.code: 200
// [ {
//   "id" : {
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//   },
//   "end_time" : 1479424149000,
//   "generated_time" : 1480987518794,
//   "job_id" : "247b07b4-affb-45cd-b041-fa37443f7147",
//   "mo_id" : "udacity-ch3",
//   "driver_id" : "",
//   "start_time" : 1479421383000,
//   "trip_id" : "udacity-ch3-north"
// } ]

// %%
val trip_uuid = "7fbdc6af-179b-4346-9f2d-65d382f30429"
val response = Http(driverInsightsServiceProps.get("trip_analytics_url").get).
    param("tenant_id", driverInsightsServiceInfo.value.get("tenant_id").get).
    param("trip_uuid", trip_uuid).
    auth(driverInsightsServiceProps.get("username").get, driverInsightsServiceProps.get("password").get).
    option(HttpOptions.readTimeout(300000)).
    header("accept", "application/json").
    header("content-type", "application/json").asString
println(s"response.code: ${response.code}")
println(response.body)
// Out:
// response.code: 200
// {
//   "id" : {
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//   },
//   "end_altitude" : 0.0,
//   "end_latitude" : 37.5503832582108,
//   "end_longitude" : -122.3120112947789,
//   "end_time" : 1479424149000,
//   "generated_time" : 1480987518794,
//   "mo_id" : "udacity-ch3",
//   "driver_id" : "",
//   "start_altitude" : 0.0,
//   "start_latitude" : 37.4019766,
//   "start_longitude" : -122.114744,
//   "start_time" : 1479421383000,
//   "trip_id" : "udacity-ch3-north",
//   "ctx_sub_trips" : [ {
//     "id" : {
//       "sub_trip_id" : "d4f784c9-21b1-46cd-8560-e218b1e3853b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 62.84220840634381,
//     "avg_speed" : 31.421104203171904,
//     "end_latitude" : 37.4664285,
//     "end_longitude" : -122.2078622,
//     "end_time" : 1479422617000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46667346515379,
//     "start_longitude" : -122.2085025290575,
//     "start_time" : 1479422615000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807135,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "d4f784c9-21b1-46cd-8560-e218b1e3853b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807136,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "d4f784c9-21b1-46cd-8560-e218b1e3853b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807137,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "d4f784c9-21b1-46cd-8560-e218b1e3853b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "915515b2-6d42-4bcc-a857-121730aee62d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 62.62612580612223,
//     "avg_speed" : 62.62612580612223,
//     "end_latitude" : 37.466672158171455,
//     "end_longitude" : -122.208500718659,
//     "end_time" : 1479422618000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4664285,
//     "start_longitude" : -122.2078622,
//     "start_time" : 1479422617000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807138,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "915515b2-6d42-4bcc-a857-121730aee62d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807139,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "915515b2-6d42-4bcc-a857-121730aee62d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807140,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "915515b2-6d42-4bcc-a857-121730aee62d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "91f64aaa-0851-44b6-bb6d-35232547dcf1",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 62.62612580612223,
//     "avg_speed" : 62.62612580612223,
//     "end_latitude" : 37.4664285,
//     "end_longitude" : -122.2078622,
//     "end_time" : 1479422619000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.466672158171455,
//     "start_longitude" : -122.208500718659,
//     "start_time" : 1479422618000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807141,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "91f64aaa-0851-44b6-bb6d-35232547dcf1",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807142,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "91f64aaa-0851-44b6-bb6d-35232547dcf1",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807143,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "91f64aaa-0851-44b6-bb6d-35232547dcf1",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "9c297a32-d0f7-4937-ab17-a5d3d7d3339d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 63.89120782745171,
//     "avg_speed" : 21.297069275817236,
//     "end_latitude" : 37.466814620565025,
//     "end_longitude" : -122.20839786920082,
//     "end_time" : 1479422622000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4664285,
//     "start_longitude" : -122.2078622,
//     "start_time" : 1479422619000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807144,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "9c297a32-d0f7-4937-ab17-a5d3d7d3339d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807145,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "9c297a32-d0f7-4937-ab17-a5d3d7d3339d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807146,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "9c297a32-d0f7-4937-ab17-a5d3d7d3339d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "23cac9f9-e58e-4644-8635-2bea3f8e390e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 63.89120782745171,
//     "avg_speed" : 31.945603913725854,
//     "end_latitude" : 37.4664285,
//     "end_longitude" : -122.2078622,
//     "end_time" : 1479422624000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.466814620565025,
//     "start_longitude" : -122.20839786920082,
//     "start_time" : 1479422622000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807147,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "23cac9f9-e58e-4644-8635-2bea3f8e390e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807148,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "23cac9f9-e58e-4644-8635-2bea3f8e390e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807149,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "23cac9f9-e58e-4644-8635-2bea3f8e390e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "20d91607-48b5-43b4-9ea2-9f1e9353f9bc",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 62.62612580612223,
//     "avg_speed" : 31.313062903061116,
//     "end_latitude" : 37.466672158171455,
//     "end_longitude" : -122.208500718659,
//     "end_time" : 1479422626000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4664285,
//     "start_longitude" : -122.2078622,
//     "start_time" : 1479422624000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807150,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "20d91607-48b5-43b4-9ea2-9f1e9353f9bc",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807151,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "20d91607-48b5-43b4-9ea2-9f1e9353f9bc",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807152,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "20d91607-48b5-43b4-9ea2-9f1e9353f9bc",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "903d9b0b-5a50-4c84-8f24-709d451e2bed",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 133.19458475078173,
//     "avg_speed" : 26.638916950156347,
//     "end_latitude" : 37.46729587154556,
//     "end_longitude" : -122.20890275267676,
//     "end_time" : 1479422632000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4664285,
//     "start_longitude" : -122.2078622,
//     "start_time" : 1479422627000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807156,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "903d9b0b-5a50-4c84-8f24-709d451e2bed",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807157,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "903d9b0b-5a50-4c84-8f24-709d451e2bed",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807158,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "903d9b0b-5a50-4c84-8f24-709d451e2bed",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "a742fdb2-dcc1-49f5-ad27-85be102fc5d3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 62.62612580612223,
//     "avg_speed" : 62.62612580612223,
//     "end_latitude" : 37.4664285,
//     "end_longitude" : -122.2078622,
//     "end_time" : 1479422627000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.466672158171455,
//     "start_longitude" : -122.208500718659,
//     "start_time" : 1479422626000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807154,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "a742fdb2-dcc1-49f5-ad27-85be102fc5d3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807153,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "a742fdb2-dcc1-49f5-ad27-85be102fc5d3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807155,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "a742fdb2-dcc1-49f5-ad27-85be102fc5d3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "4b0cc104-568d-4aa3-95a0-a3d10027e0eb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 74.22828062532939,
//     "avg_speed" : 74.22828062532939,
//     "end_latitude" : 37.466695490085634,
//     "end_longitude" : -122.20853303742969,
//     "end_time" : 1479422633000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46729587154556,
//     "start_longitude" : -122.20890275267676,
//     "start_time" : 1479422632000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807159,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "4b0cc104-568d-4aa3-95a0-a3d10027e0eb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807160,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 4,
//       "context_name" : "Urban-road",
//       "sub_trip_id" : "4b0cc104-568d-4aa3-95a0-a3d10027e0eb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807182,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "4b0cc104-568d-4aa3-95a0-a3d10027e0eb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "e56802f4-60c8-4719-964d-f7411e363f0b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 72.42542707793754,
//     "avg_speed" : 18.106356769484385,
//     "end_latitude" : 37.46725292638505,
//     "end_longitude" : -122.2089455567937,
//     "end_time" : 1479422637000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.466695490085634,
//     "start_longitude" : -122.20853303742969,
//     "start_time" : 1479422633000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807184,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "e56802f4-60c8-4719-964d-f7411e363f0b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807186,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "e56802f4-60c8-4719-964d-f7411e363f0b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807189,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "e56802f4-60c8-4719-964d-f7411e363f0b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "e9d2acf9-f1de-481b-83fb-1057fbd348d2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 31.446999478570277,
//     "avg_speed" : 15.723499739285138,
//     "end_latitude" : 37.46704821446176,
//     "end_longitude" : -122.20872193651897,
//     "end_time" : 1479422639000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46725292638505,
//     "start_longitude" : -122.2089455567937,
//     "start_time" : 1479422637000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807191,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "e9d2acf9-f1de-481b-83fb-1057fbd348d2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807193,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 4,
//       "context_name" : "Urban-road",
//       "sub_trip_id" : "e9d2acf9-f1de-481b-83fb-1057fbd348d2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807195,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "e9d2acf9-f1de-481b-83fb-1057fbd348d2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "6eb321cc-035c-4be6-b5ac-35e175db8718",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 29.682738584670535,
//     "avg_speed" : 29.682738584670535,
//     "end_latitude" : 37.4672276,
//     "end_longitude" : -122.2089708,
//     "end_time" : 1479422640000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46704821446176,
//     "start_longitude" : -122.20872193651897,
//     "start_time" : 1479422639000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807197,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "6eb321cc-035c-4be6-b5ac-35e175db8718",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807199,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "6eb321cc-035c-4be6-b5ac-35e175db8718",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807200,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "6eb321cc-035c-4be6-b5ac-35e175db8718",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "00eb7068-2790-41c2-9e4b-f9647a425d0f",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 20.83273715460421,
//     "avg_speed" : 6.944245718201404,
//     "end_latitude" : 37.46716620163368,
//     "end_longitude" : -122.20918461564925,
//     "end_time" : 1479422643000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4672276,
//     "start_longitude" : -122.2089708,
//     "start_time" : 1479422640000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807201,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "00eb7068-2790-41c2-9e4b-f9647a425d0f",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807202,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 4,
//       "context_name" : "Urban-road",
//       "sub_trip_id" : "00eb7068-2790-41c2-9e4b-f9647a425d0f",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807203,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "00eb7068-2790-41c2-9e4b-f9647a425d0f",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "3d80bb2b-2229-4569-94e4-64c43a8041d5",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 88.12094235756189,
//     "avg_speed" : 29.37364745252063,
//     "end_latitude" : 37.467808493661046,
//     "end_longitude" : -122.20975666932968,
//     "end_time" : 1479422646000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46716620163368,
//     "start_longitude" : -122.20918461564925,
//     "start_time" : 1479422643000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807204,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "3d80bb2b-2229-4569-94e4-64c43a8041d5",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807205,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "3d80bb2b-2229-4569-94e4-64c43a8041d5",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807206,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "3d80bb2b-2229-4569-94e4-64c43a8041d5",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "b80775f9-c1ec-4eee-9e88-de03249994a3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 32.03453502271178,
//     "avg_speed" : 16.01726751135589,
//     "end_latitude" : 37.46752908070464,
//     "end_longitude" : -122.20968426390917,
//     "end_time" : 1479422648000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.467808493661046,
//     "start_longitude" : -122.20975666932968,
//     "start_time" : 1479422646000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807207,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 1,
//       "context_name" : "steadyFlow",
//       "sub_trip_id" : "b80775f9-c1ec-4eee-9e88-de03249994a3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807208,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "b80775f9-c1ec-4eee-9e88-de03249994a3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807209,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "b80775f9-c1ec-4eee-9e88-de03249994a3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "a35599ea-3abf-4db7-880c-0933dce717e9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 30.999503290019423,
//     "avg_speed" : 30.999503290019423,
//     "end_latitude" : 37.4678011,
//     "end_longitude" : -122.2097638,
//     "end_time" : 1479422649000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46752908070464,
//     "start_longitude" : -122.20968426390917,
//     "start_time" : 1479422648000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807211,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "a35599ea-3abf-4db7-880c-0933dce717e9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807222,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "a35599ea-3abf-4db7-880c-0933dce717e9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807224,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "a35599ea-3abf-4db7-880c-0933dce717e9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "266576a1-1c34-469a-94df-01c15195ac72",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 15.015318905501804,
//     "avg_speed" : 7.507659452750902,
//     "end_latitude" : 37.46789182271356,
//     "end_longitude" : -122.20988971550003,
//     "end_time" : 1479422651000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4678011,
//     "start_longitude" : -122.2097638,
//     "start_time" : 1479422649000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807226,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 1,
//       "context_name" : "steadyFlow",
//       "sub_trip_id" : "266576a1-1c34-469a-94df-01c15195ac72",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807228,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "266576a1-1c34-469a-94df-01c15195ac72",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807230,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "266576a1-1c34-469a-94df-01c15195ac72",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "df1f3125-678a-4cd2-9cea-eee1d4688561",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 15.015318905501804,
//     "avg_speed" : 15.015318905501804,
//     "end_latitude" : 37.4678011,
//     "end_longitude" : -122.2097638,
//     "end_time" : 1479422652000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46789182271356,
//     "start_longitude" : -122.20988971550003,
//     "start_time" : 1479422651000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807232,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "df1f3125-678a-4cd2-9cea-eee1d4688561",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807234,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "df1f3125-678a-4cd2-9cea-eee1d4688561",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807236,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "df1f3125-678a-4cd2-9cea-eee1d4688561",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "1432df1d-affe-4e8e-abff-15724c9d8c5b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 40.19877140485209,
//     "avg_speed" : 40.19877140485209,
//     "end_latitude" : 37.468043981530506,
//     "end_longitude" : -122.21010089914698,
//     "end_time" : 1479422653000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4678011,
//     "start_longitude" : -122.2097638,
//     "start_time" : 1479422652000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807238,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "1432df1d-affe-4e8e-abff-15724c9d8c5b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807240,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "1432df1d-affe-4e8e-abff-15724c9d8c5b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807242,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "1432df1d-affe-4e8e-abff-15724c9d8c5b",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "ec5a7f85-12f6-43ef-a39d-f273133eb7f3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 40.19877140485209,
//     "avg_speed" : 40.19877140485209,
//     "end_latitude" : 37.4678011,
//     "end_longitude" : -122.2097638,
//     "end_time" : 1479422654000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.468043981530506,
//     "start_longitude" : -122.21010089914698,
//     "start_time" : 1479422653000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807244,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "ec5a7f85-12f6-43ef-a39d-f273133eb7f3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807246,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "ec5a7f85-12f6-43ef-a39d-f273133eb7f3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807248,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "ec5a7f85-12f6-43ef-a39d-f273133eb7f3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "300218d6-c1f9-4fcc-b7c2-7687160208d4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 112.18150564281834,
//     "avg_speed" : 112.18150564281834,
//     "end_latitude" : 37.4683564,
//     "end_longitude" : -122.2108234,
//     "end_time" : 1479422655000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4678011,
//     "start_longitude" : -122.2097638,
//     "start_time" : 1479422654000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807250,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "300218d6-c1f9-4fcc-b7c2-7687160208d4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807252,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "300218d6-c1f9-4fcc-b7c2-7687160208d4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807254,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "300218d6-c1f9-4fcc-b7c2-7687160208d4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "37875717-41bd-4d37-9204-170d7b50d851",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 61.98395643660014,
//     "avg_speed" : 12.396791287320028,
//     "end_latitude" : 37.468426546570534,
//     "end_longitude" : -122.21076475552302,
//     "end_time" : 1479422660000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.4683564,
//     "start_longitude" : -122.2108234,
//     "start_time" : 1479422655000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807256,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "37875717-41bd-4d37-9204-170d7b50d851",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807258,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "37875717-41bd-4d37-9204-170d7b50d851",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807260,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "37875717-41bd-4d37-9204-170d7b50d851",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "f1cbdc19-418c-4b28-982e-3270267181cb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 34.3914660922853,
//     "avg_speed" : 34.3914660922853,
//     "end_latitude" : 37.46856961727527,
//     "end_longitude" : -122.21110960508301,
//     "end_time" : 1479422661000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.468426546570534,
//     "start_longitude" : -122.21076475552302,
//     "start_time" : 1479422660000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 804958,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "f1cbdc19-418c-4b28-982e-3270267181cb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804959,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "f1cbdc19-418c-4b28-982e-3270267181cb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804960,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "f1cbdc19-418c-4b28-982e-3270267181cb",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "a1989b5a-ca19-4b13-8e20-12406fc76fc4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 34.23983619796949,
//     "avg_speed" : 34.23983619796949,
//     "end_latitude" : 37.468412410489535,
//     "end_longitude" : -122.2107765736785,
//     "end_time" : 1479422662000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.46856961727527,
//     "start_longitude" : -122.21110960508301,
//     "start_time" : 1479422661000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 804961,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "a1989b5a-ca19-4b13-8e20-12406fc76fc4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804962,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "a1989b5a-ca19-4b13-8e20-12406fc76fc4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804963,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "a1989b5a-ca19-4b13-8e20-12406fc76fc4",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "45ed655c-877f-4048-a8aa-73918c99fd1d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 301.581299250833,
//     "avg_speed" : 25.131774937569418,
//     "end_latitude" : 37.469603950532004,
//     "end_longitude" : -122.21249774007569,
//     "end_time" : 1479422674000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.468412410489535,
//     "start_longitude" : -122.2107765736785,
//     "start_time" : 1479422662000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 804964,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 1,
//       "context_name" : "steadyFlow",
//       "sub_trip_id" : "45ed655c-877f-4048-a8aa-73918c99fd1d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804965,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "45ed655c-877f-4048-a8aa-73918c99fd1d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 804966,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "45ed655c-877f-4048-a8aa-73918c99fd1d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "42c1ec34-916e-4898-9343-c29e8e59a77e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 221.42555666638344,
//     "avg_speed" : 27.67819458329793,
//     "end_latitude" : 37.5057704,
//     "end_longitude" : -122.2573236,
//     "end_time" : 1479423400000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.50436086047133,
//     "start_longitude" : -122.25669443729994,
//     "start_time" : 1479423392000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806013,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "42c1ec34-916e-4898-9343-c29e8e59a77e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806015,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "42c1ec34-916e-4898-9343-c29e8e59a77e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806017,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "42c1ec34-916e-4898-9343-c29e8e59a77e",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "321e0911-babd-4b39-9dec-af25ec6e9a69",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 80.30747729721514,
//     "avg_speed" : 80.30747729721514,
//     "end_latitude" : 37.505285265126474,
//     "end_longitude" : -122.25799747247117,
//     "end_time" : 1479423401000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5057704,
//     "start_longitude" : -122.2573236,
//     "start_time" : 1479423400000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806019,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "321e0911-babd-4b39-9dec-af25ec6e9a69",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806021,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "321e0911-babd-4b39-9dec-af25ec6e9a69",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806022,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "321e0911-babd-4b39-9dec-af25ec6e9a69",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "98a0a2a5-c7ca-43e4-b4aa-3d7a44119627",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 101.33141437247757,
//     "avg_speed" : 101.33141437247757,
//     "end_latitude" : 37.5061864,
//     "end_longitude" : -122.2578133,
//     "end_time" : 1479423402000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.505285265126474,
//     "start_longitude" : -122.25799747247117,
//     "start_time" : 1479423401000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806024,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "98a0a2a5-c7ca-43e4-b4aa-3d7a44119627",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806026,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "98a0a2a5-c7ca-43e4-b4aa-3d7a44119627",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806028,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "98a0a2a5-c7ca-43e4-b4aa-3d7a44119627",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "b27ef278-8b64-4a4a-a89b-5bf4ce0140e0",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 85.3083067933024,
//     "avg_speed" : 85.3083067933024,
//     "end_latitude" : 37.50550465249477,
//     "end_longitude" : -122.25825889681508,
//     "end_time" : 1479423403000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5061864,
//     "start_longitude" : -122.2578133,
//     "start_time" : 1479423402000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806030,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "b27ef278-8b64-4a4a-a89b-5bf4ce0140e0",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806032,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "b27ef278-8b64-4a4a-a89b-5bf4ce0140e0",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806034,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "b27ef278-8b64-4a4a-a89b-5bf4ce0140e0",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "c2993cc0-e29c-4d5d-af48-2f512219bdd7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 435.2700575078025,
//     "avg_speed" : 18.924785109034893,
//     "end_latitude" : 37.5075751,
//     "end_longitude" : -122.2607253,
//     "end_time" : 1479423426000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.50550465249477,
//     "start_longitude" : -122.25825889681508,
//     "start_time" : 1479423403000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806036,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "c2993cc0-e29c-4d5d-af48-2f512219bdd7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806053,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "c2993cc0-e29c-4d5d-af48-2f512219bdd7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806055,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "c2993cc0-e29c-4d5d-af48-2f512219bdd7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "287c6bc7-5944-4335-b1a0-da0f28e661f2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 20.532938563920645,
//     "avg_speed" : 20.532938563920645,
//     "end_latitude" : 37.5077112,
//     "end_longitude" : -122.2608826,
//     "end_time" : 1479423427000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5075751,
//     "start_longitude" : -122.2607253,
//     "start_time" : 1479423426000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 806057,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "287c6bc7-5944-4335-b1a0-da0f28e661f2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806059,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 5,
//       "context_name" : "Others/Urban path or alley",
//       "sub_trip_id" : "287c6bc7-5944-4335-b1a0-da0f28e661f2",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 806061,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
// ...
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 98.69154716742818,
//     "avg_speed" : 12.336443395928523,
//     "end_latitude" : 37.5498849,
//     "end_longitude" : -122.3112525,
//     "end_time" : 1479424121000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5492048086745,
//     "start_longitude" : -122.31073911271301,
//     "start_time" : 1479424113000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807412,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "434448c6-dd2c-49be-9c4c-f6ab54f8dd7c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807413,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "434448c6-dd2c-49be-9c4c-f6ab54f8dd7c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807414,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "434448c6-dd2c-49be-9c4c-f6ab54f8dd7c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "23f375a1-ad81-4bbf-a857-e7301d48298d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 27.164357657898115,
//     "avg_speed" : 27.164357657898115,
//     "end_latitude" : 37.54995319579846,
//     "end_longitude" : -122.31154769491718,
//     "end_time" : 1479424122000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5498849,
//     "start_longitude" : -122.3112525,
//     "start_time" : 1479424121000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807415,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "23f375a1-ad81-4bbf-a857-e7301d48298d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807416,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 1,
//       "context_name" : "Highway/motor way",
//       "sub_trip_id" : "23f375a1-ad81-4bbf-a857-e7301d48298d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807417,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "23f375a1-ad81-4bbf-a857-e7301d48298d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "3c432a08-bd5a-4dab-80d9-81e4767107de",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 78.87800296162483,
//     "avg_speed" : 15.775600592324967,
//     "end_latitude" : 37.550398815300355,
//     "end_longitude" : -122.31202754261004,
//     "end_time" : 1479424127000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.54995319579846,
//     "start_longitude" : -122.31154769491718,
//     "start_time" : 1479424122000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807418,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "3c432a08-bd5a-4dab-80d9-81e4767107de",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807419,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "3c432a08-bd5a-4dab-80d9-81e4767107de",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807420,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "3c432a08-bd5a-4dab-80d9-81e4767107de",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "5e55a605-b6fb-43f9-af4e-1673af0c001a",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 4.379619798080775,
//     "avg_speed" : 4.379619798080775,
//     "end_latitude" : 37.55042826229168,
//     "end_longitude" : -122.31206053490175,
//     "end_time" : 1479424128000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.550398815300355,
//     "start_longitude" : -122.31202754261004,
//     "start_time" : 1479424127000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807421,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "5e55a605-b6fb-43f9-af4e-1673af0c001a",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807422,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 1,
//       "context_name" : "Highway/motor way",
//       "sub_trip_id" : "5e55a605-b6fb-43f9-af4e-1673af0c001a",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807423,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "5e55a605-b6fb-43f9-af4e-1673af0c001a",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "7b7d8341-caf1-4431-ab61-99fff2c96e6c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 48.59318693083678,
//     "avg_speed" : 12.148296732709195,
//     "end_latitude" : 37.55078623150647,
//     "end_longitude" : -122.31232399917218,
//     "end_time" : 1479424132000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.55042826229168,
//     "start_longitude" : -122.31206053490175,
//     "start_time" : 1479424128000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807424,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "7b7d8341-caf1-4431-ab61-99fff2c96e6c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807425,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "7b7d8341-caf1-4431-ab61-99fff2c96e6c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807426,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "7b7d8341-caf1-4431-ab61-99fff2c96e6c",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "ec078cbf-d585-442e-b1da-abf80144458d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 11.125633532798604,
//     "avg_speed" : 11.125633532798604,
//     "end_latitude" : 37.55077963568162,
//     "end_longitude" : -122.31244963100714,
//     "end_time" : 1479424133000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.55078623150647,
//     "start_longitude" : -122.31232399917218,
//     "start_time" : 1479424132000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807427,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : -1,
//       "context_name" : "unknown",
//       "sub_trip_id" : "ec078cbf-d585-442e-b1da-abf80144458d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807428,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 1,
//       "context_name" : "Highway/motor way",
//       "sub_trip_id" : "ec078cbf-d585-442e-b1da-abf80144458d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807429,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "ec078cbf-d585-442e-b1da-abf80144458d",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "3b2216a3-2f07-4130-bf3b-29a4b64e30d9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 40.33440701121545,
//     "avg_speed" : 20.167203505607723,
//     "end_latitude" : 37.5511288,
//     "end_longitude" : -122.3124745,
//     "end_time" : 1479424135000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.55077963568162,
//     "start_longitude" : -122.31244963100714,
//     "start_time" : 1479424133000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807430,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "3b2216a3-2f07-4130-bf3b-29a4b64e30d9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807431,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "3b2216a3-2f07-4130-bf3b-29a4b64e30d9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807432,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "3b2216a3-2f07-4130-bf3b-29a4b64e30d9",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "d2db4456-14c0-49aa-ab1e-4d19650464a7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 218.29594872595393,
//     "avg_speed" : 19.845086247813995,
//     "end_latitude" : 37.55034784755194,
//     "end_longitude" : -122.31197255106594,
//     "end_time" : 1479424146000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.5511288,
//     "start_longitude" : -122.3124745,
//     "start_time" : 1479424135000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807433,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "d2db4456-14c0-49aa-ab1e-4d19650464a7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807434,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 1,
//       "context_name" : "Highway/motor way",
//       "sub_trip_id" : "d2db4456-14c0-49aa-ab1e-4d19650464a7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807435,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "d2db4456-14c0-49aa-ab1e-4d19650464a7",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   }, {
//     "id" : {
//       "sub_trip_id" : "cf2bfa0f-9f85-4b8e-9877-063970ec95e3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     },
//     "length" : 5.7264187161047495,
//     "avg_speed" : 1.9088062387015832,
//     "end_latitude" : 37.5503832582108,
//     "end_longitude" : -122.3120112947789,
//     "end_time" : 1479424149000,
//     "mo_id" : "udacity-ch3",
//     "driver_id" : "",
//     "start_latitude" : 37.55034784755194,
//     "start_longitude" : -122.31197255106594,
//     "start_time" : 1479424146000,
//     "trip_id" : "udacity-ch3-north",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429",
//     "ctx_features" : [ {
//       "id" : 807436,
//       "context_category" : "speedPattern",
//       "context_category_id" : 0,
//       "context_id" : 2,
//       "context_name" : "severeCongestion",
//       "sub_trip_id" : "cf2bfa0f-9f85-4b8e-9877-063970ec95e3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807437,
//       "context_category" : "roadType",
//       "context_category_id" : 3,
//       "context_id" : 3,
//       "context_name" : "Secondary Extra-urban road/urban primary",
//       "sub_trip_id" : "cf2bfa0f-9f85-4b8e-9877-063970ec95e3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     }, {
//       "id" : 807438,
//       "context_category" : "timeRange",
//       "context_category_id" : 4,
//       "context_id" : 2,
//       "context_name" : "eveningPeakHours",
//       "sub_trip_id" : "cf2bfa0f-9f85-4b8e-9877-063970ec95e3",
//       "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711"
//     } ],
//     "driving_behavior_details" : [ ]
//   } ],
//   "trip_features" : [ {
//     "id" : 255911,
//     "feature_name" : "night_driving_time",
//     "feature_value" : "2764.0",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255912,
//     "feature_name" : "rush_hour_driving",
//     "feature_value" : "0.0",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255913,
//     "feature_name" : "day_of_week",
//     "feature_value" : "5",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255914,
//     "feature_name" : "day_of_month",
//     "feature_value" : "17",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255915,
//     "feature_name" : "month_of_year",
//     "feature_value" : "11",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255916,
//     "feature_name" : "max_speed",
//     "feature_value" : "19.201838",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255917,
//     "feature_name" : "idle_time",
//     "feature_value" : "611.0",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255918,
//     "feature_name" : "time_span",
//     "feature_value" : "2766.0",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255919,
//     "feature_name" : "distance",
//     "feature_value" : "47420.02496211132",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   }, {
//     "id" : 255920,
//     "feature_name" : "average_speed",
//     "feature_value" : "61.71803682704293",
//     "tenant_id" : "c97244f8-e5b1-4982-94c4-0b4bd5c5b711",
//     "trip_uuid" : "7fbdc6af-179b-4346-9f2d-65d382f30429"
//   } ]
// }
